# %% [markdown]
# ---
# # csv 파싱
# ---

# %%
import pandas as pd
import json

# %%
mama = pd.read_csv("../mama.csv")
mama
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# {result":[{"cashSellingPrice":1447.23 countryCode:"US" cashBuyingPrice:1498.77 ttBuyingPrice:1458.6 countryNameKr:"미국" currencyCode:"USD" ttSellingPrice:1487.4 countryNameEn:"United States of America" currencyUnit:1 basePrice:1473}   {"cashSellingPrice":918.03 countryCode:"JP" cashBuyingPrice:950.73 ttBuyingPrice:925.23 countryNameKr:"일본" currencyCode:"JPY" ttSellingPrice:943.53 countryNameEn:"Japan" currencyUnit:100 basePrice:934.38} {"cashSellingPrice":1481.66 countryCode:"EU" cashBuyingPrice:1541.82 ttBuyingPrice:1496.63 countryNameKr:"유럽" currencyCode:"EUR" ttSellingPrice:1526.85 countryNameEn:"Europe" currencyUnit:1 basePrice:1511.74} {"cashSellingPrice":190.6 countryCode:"CN" cashBuyingPrice:210.66 ttBuyingPrice:198.63 countryNameKr:"중국" currencyCode:"CNY" ttSellingPrice:202.63 countryNameEn:"China" currencyUnit:1 basePrice:200.63} {"cashSellingPrice":185.67 countryCode:"HK" cashBuyingPrice:193.13 ttBuyingPrice:187.51 countryNameKr:"홍콩" currencyCode:"HKD" ttSellingPrice:191.29 countryNameEn:"Hong Kong" currencyUnit:1 basePrice:189.4}  {"cashSellingPrice":40.27 countryCode:"TH" cashBuyingPrice:44.97 ttBuyingPrice:42.41 countryNameKr:"태국" currencyCode:"THB" ttSellingPrice:43.25 countryNameEn:"Thailand" currencyUnit:1 basePrice:42.83} {"cashSellingPrice":40.27 countryCode:"TW" cashBuyingPrice:50.6 ttBuyingPrice:0 countryNameKr:"대만" currencyCode:"TWD" ttSellingPrice:0 countryNameEn:"Taiwan" currencyUnit:1 basePrice:44.74} {"cashSellingPrice":23.32 countryCode:"PH" cashBuyingPrice:27.94 ttBuyingPrice:25.15 countryNameKr:"필리핀" currencyCode:"PHP" ttSellingPrice:25.65 countryNameEn:"Philippines" currencyUnit:1 basePrice:25.4}  {"cashSellingPrice":1054.37 countryCode:"SG" cashBuyingPrice:1097.17 ttBuyingPrice:1065.02 countryNameKr:"싱가포르" currencyCode:"SGD" ttSellingPrice:1086.52 countryNameEn:"Singapore" currencyUnit:1 basePrice:1075.77} {"cashSellingPrice":896.21 countryCode:"AU" cashBuyingPrice:932.23 ttBuyingPrice:905.08 countryNameKr:"호주" currencyCode:"AUD" ttSellingPrice:923.36 countryNameEn:"Australia" currencyUnit:1 basePrice:914.22} {"cashSellingPrice":5.11 countryCode:"VN" cashBuyingPrice:6.47 ttBuyingPrice:5.74 countryNameKr:"베트남" currencyCode:"VND" ttSellingPrice:5.84 countryNameEn:"Viet Nam" currencyUnit:100 basePrice:5.79} {"cashSellingPrice":1786.94 countryCode:"GB" cashBuyingPrice:1858.74 ttBuyingPrice:1804.62 countryNameKr:"영국" currencyCode:"GBP" ttSellingPrice:1841.06 countryNameEn:"United Kingdom" currencyUnit:1 basePrice:1822.84} {"cashSellingPrice":1001.07 countryCode:"CA" cashBuyingPrice:1041.29 ttBuyingPrice:1010.97 countryNameKr:"캐나다" currencyCode:"CAD" ttSellingPrice:1031.39 countryNameEn:"Canada" currencyUnit:1 basePrice:1021.18} {"cashSellingPrice":304.57 countryCode:"MY" cashBuyingPrice:353.23 ttBuyingPrice:325.62 countryNameKr:"말레이시아" currencyCode:"MYR" ttSellingPrice:0 countryNameEn:"Malaysia" currencyUnit:1 basePrice:328.9}  {"cashSellingPrice":10.48 countryCode:"RU" cashBuyingPrice:13.9  ttBuyingPrice:12.26 countryNameKr:"러시아" currencyCode:"RUB" ttSellingPrice:13.14 countryNameEn:"Russia" currencyUnit:1 basePrice:12.7}  {"cashSellingPrice":72.45 countryCode:"ZA" cashBuyingPrice:85.05 ttBuyingPrice:77.81 countryNameKr:"남아프리카 공화국" currencyCode:"ZAR" ttSellingPrice:79.69 countryNameEn:"South Africa" currencyUnit:1 basePrice:78.75} {"cashSellingPrice":122.15 countryCode:"NO" cashBuyingPrice:133.8  ttBuyingPrice:128.24 countryNameKr:"노르웨이" currencyCode:"NOK" ttSellingPrice:130.82 countryNameEn:"Norway" currencyUnit:1 basePrice:129.53} {"cashSellingPrice":808.49 countryCode:"NZ" cashBuyingPrice:840.97 ttBuyingPrice:816.49 countryNameKr:"뉴질랜드" currencyCode:"NZD" ttSellingPrice:832.97 countryNameEn:"New Zealand" currencyUnit:1 basePrice:824.73} {"cashSellingPrice":191.12 countryCode:"DK" cashBuyingPrice:209.35 ttBuyingPrice:200.65 countryNameKr:"덴마크" currencyCode:"DKK" ttSellingPrice:204.69 countryNameEn:"Denmark" currencyUnit:1 basePrice:202.67} {"cashSellingPrice":63.92 countryCode:"MX" cashBuyingPrice:78 ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# {result":[{"cashSellingPrice":1432    countryCode:"US" cashBuyingPrice:1483    ttBuyingPrice:1443.3 countryNameKr:"미국" currencyCode:"USD" ttSellingPrice:1471.7 countryNameEn:"United States of America" currencyUnit:1 basePrice:1457.5} {"cashSellingPrice":922.92 countryCode:"JP" cashBuyingPrice:955.78 ttBuyingPrice:930.15 countryNameKr:"일본" currencyCode:"JPY" ttSellingPrice:948.55 countryNameEn:"Japan" currencyUnit:100 basePrice:939.35} {"cashSellingPrice":1480.99 countryCode:"EU" cashBuyingPrice:1541.13 ttBuyingPrice:1495.95 countryNameKr:"유럽" currencyCode:"EUR" ttSellingPrice:1526.17 countryNameEn:"Europe" currencyUnit:1 basePrice:1511.06} {"cashSellingPrice":189.3 countryCode:"CN" cashBuyingPrice:209.22 ttBuyingPrice:197.27 countryNameKr:"중국" currencyCode:"CNY" ttSellingPrice:201.25 countryNameEn:"China" currencyUnit:1 basePrice:199.26} {"cashSellingPrice":183.35 countryCode:"HK" cashBuyingPrice:190.71 ttBuyingPrice:185.16 countryNameKr:"홍콩" currencyCode:"HKD" ttSellingPrice:188.9  countryNameEn:"Hong Kong" currencyUnit:1 basePrice:187.03} {"cashSellingPrice":40.55 countryCode:"TH" cashBuyingPrice:45.28 ttBuyingPrice:42.7  countryNameKr:"태국" currencyCode:"THB" ttSellingPrice:43.56 countryNameEn:"Thailand" currencyUnit:1 basePrice:43.13} {"cashSellingPrice":39.79 countryCode:"TW" cashBuyingPrice:50   ttBuyingPrice:0 countryNameKr:"대만" currencyCode:"TWD" ttSellingPrice:0 countryNameEn:"Taiwan" currencyUnit:1 basePrice:44.21} {"cashSellingPrice":22.91 countryCode:"PH" cashBuyingPrice:27.44 ttBuyingPrice:24.71 countryNameKr:"필리핀" currencyCode:"PHP" ttSellingPrice:25.19 countryNameEn:"Philippines" currencyUnit:1 basePrice:24.95} {"cashSellingPrice":1051.03 countryCode:"SG" cashBuyingPrice:1093.69 ttBuyingPrice:1061.64 countryNameKr:"싱가포르" currencyCode:"SGD" ttSellingPrice:1083.08 countryNameEn:"Singapore" currencyUnit:1 basePrice:1072.36} {"cashSellingPrice":888.07 countryCode:"AU" cashBuyingPrice:923.75 ttBuyingPrice:896.86 countryNameKr:"호주" currencyCode:"AUD" ttSellingPrice:914.96 countryNameEn:"Australia" currencyUnit:1 basePrice:905.91} {"cashSellingPrice":5.19 countryCode:"VN" cashBuyingPrice:6.57 ttBuyingPrice:5.83 countryNameKr:"베트남" currencyCode:"VND" ttSellingPrice:5.93 countryNameEn:"Viet Nam" currencyUnit:100 basePrice:5.88} {"cashSellingPrice":1771.63 countryCode:"GB" cashBuyingPrice:1842.83 ttBuyingPrice:1789.16 countryNameKr:"영국" currencyCode:"GBP" ttSellingPrice:1825.3  countryNameEn:"United Kingdom" currencyUnit:1 basePrice:1807.23} {"cashSellingPrice":984.05  countryCode:"CA" cashBuyingPrice:1023.59 ttBuyingPrice:993.79  countryNameKr:"캐나다" currencyCode:"CAD" ttSellingPrice:1013.85 countryNameEn:"Canada" currencyUnit:1 basePrice:1003.82} {"cashSellingPrice":302.96 countryCode:"MY" cashBuyingPrice:351.36 ttBuyingPrice:323.89 countryNameKr:"말레이시아" currencyCode:"MYR" ttSellingPrice:0 countryNameEn:"Malaysia" currencyUnit:1 basePrice:327.16} {"cashSellingPrice":12.15 countryCode:"RU" cashBuyingPrice:16.11 ttBuyingPrice:14.21 countryNameKr:"러시아" currencyCode:"RUB" ttSellingPrice:15.23 countryNameEn:"Russia" currencyUnit:1 basePrice:14.72} {"cashSellingPrice":71.76 countryCode:"ZA" cashBuyingPrice:84.22 ttBuyingPrice:77.06 countryNameKr:"남아프리카 공화국" currencyCode:"ZAR" ttSellingPrice:78.92 countryNameEn:"South Africa" currencyUnit:1 basePrice:77.99} {"cashSellingPrice":121.42 countryCode:"NO" cashBuyingPrice:132.99 ttBuyingPrice:127.47 countryNameKr:"노르웨이" currencyCode:"NOK" ttSellingPrice:130.03 countryNameEn:"Norway" currencyUnit:1 basePrice:128.75} {"cashSellingPrice":806.06 countryCode:"NZ" cashBuyingPrice:838.44 ttBuyingPrice:814.03 countryNameKr:"뉴질랜드" currencyCode:"NZD" ttSellingPrice:830.47 countryNameEn:"New Zealand" currencyUnit:1 basePrice:822.25} {"cashSellingPrice":190.96 countryCode:"DK" cashBuyingPrice:209.18 ttBuyingPrice:200.48 countryNameKr:"덴마크" currencyCode:"DKK" ttSellingPrice:204.52 countryNameEn:"Denmark" currencyUnit:1 basePrice:202.5}  {"cashSellingPrice":62.98 countryCode:"MX" cashBuyingPrice:77 ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#
# [17654 rows x 1 columns]

# %%
mama['data'].value_counts()
# Out:
# data
# basePrice:3.63}]}"    3692
# basePrice:3.65}]}"    3015
# basePrice:3.64}]}"    2979
# basePrice:3.69}]}"    1975
# basePrice:3.68}]}"    1848
# basePrice:3.66}]}"    1811
# basePrice:3.7}]}"      846
# basePrice:3.62}]}"     626
# basePrice:3.71}]}"     575
# basePrice:3.67}]}"     270
# basePrice:3.61}]}"       7
# basePrice:3.72}]}"       4
# Name: count, dtype: int64

# %%
# 첫 번째 행의 데이터 확인
print("First row data:")
print(mama['data'].iloc[0])
print("\n" + "="*80 + "\n")

# 데이터의 실제 형태 확인
print("Data type:", type(mama['data'].iloc[0]))
print("Data length:", len(mama['data'].iloc[0]))
print("\n" + "="*80 + "\n")

# JSON 파싱 시도 과정 상세 출력
def test_json_parsing(json_string):
    print("1. Original string:")
    print(json_string[:200])
    
    print("\n2. After initial cleaning:")
    cleaned = json_string.strip()
    cleaned = cleaned.replace('{result"', '{"result"')
    print(cleaned[:200])
    
    try:
        parsed = json.loads(cleaned)
        print("\n3. Successfully parsed!")
        return parsed
    except json.JSONDecodeError as e:
        print("\n3. JSON decode error:")
        print(f"Error message: {str(e)}")
        print(f"Error position: {e.pos}")
        print(f"Line number: {e.lineno}")
        print(f"Column number: {e.colno}")
        return None

# 첫 번째 행에 대해 테스트
print("Testing JSON parsing on first row:")
result = test_json_parsing(mama['data'].iloc[0])
# Out:
# First row data:
# basePrice:3.66}]}"
#
# ================================================================================
#
# Data type: <class 'str'>
# Data length: 18
#
# ================================================================================
#
# Testing JSON parsing on first row:
# 1. Original string:
# basePrice:3.66}]}"
#
# 2. After initial cleaning:
# basePrice:3.66}]}"
#
# 3. JSON decode error:
# Error message: Expecting value: line 1 column 1 (char 0)
# Error position: 0
# Line number: 1
# Column number: 1

# %%
# 첫 번째 행의 데이터를 가져옵니다
first_row = mama['data'].iloc[0]

print("1. 원본 데이터 (처음 100자):")
print(first_row[:100])
print("\n")

print("2. 데이터 타입:")
print(type(first_row))
print("\n")

print("3. 중괄호의 위치:")
first_brace = first_row.find('{')
last_brace = first_row.rfind('}')
print(f"첫 중괄호 위치: {first_brace}")
print(f"마지막 중괄호 위치: {last_brace}")
print("\n")

print("4. 중괄호 사이의 내용 (처음 100자):")
content_between_braces = first_row[first_brace:last_brace+1]
print(content_between_braces[:100])
print("\n")

print("5. 문자열에 포함된 이스케이프 문자 확인:")
print(repr(first_row[:100]))
# Out:
# 1. 원본 데이터 (처음 100자):
# basePrice:3.66}]}"
#
#
# 2. 데이터 타입:
# <class 'str'>
#
#
# 3. 중괄호의 위치:
# 첫 중괄호 위치: -1
# 마지막 중괄호 위치: 16
#
#
# 4. 중괄호 사이의 내용 (처음 100자):
#
#
#
# 5. 문자열에 포함된 이스케이프 문자 확인:
# 'basePrice:3.66}]}"'

# %%
# 첫 번째 행의 데이터를 더 자세히 분석
first_row = mama['data'].iloc[0]

# 1. 문자열 내의 모든 중괄호 위치 찾기
opening_braces = [i for i, char in enumerate(first_row) if char == '{']
closing_braces = [i for i, char in enumerate(first_row) if char == '}']

print("1. 모든 중괄호 위치:")
print(f"여는 중괄호 위치들: {opening_braces}")
print(f"닫는 중괄호 위치들: {closing_braces}")
print("\n")

# 2. JSON 구조 분석
print("2. JSON 구조 분석:")
print("첫 20글자:", repr(first_row[:20]))
print("마지막 20글자:", repr(first_row[-20:]))
print("\n")

# 3. 콤마와 콜론의 위치 확인 (처음 100자 내에서)
print("3. 주요 구분자 위치 (처음 100자 내):")
commas = [i for i, char in enumerate(first_row[:100]) if char == ',']
colons = [i for i, char in enumerate(first_row[:100]) if char == ':']
print(f"콤마 위치들: {commas}")
print(f"콜론 위치들: {colons}")
# Out:
# 1. 모든 중괄호 위치:
# 여는 중괄호 위치들: []
# 닫는 중괄호 위치들: [14, 16]
#
#
# 2. JSON 구조 분석:
# 첫 20글자: 'basePrice:3.66}]}"'
# 마지막 20글자: 'basePrice:3.66}]}"'
#
#
# 3. 주요 구분자 위치 (처음 100자 내):
# 콤마 위치들: []
# 콜론 위치들: [9]

# %%
# 첫 번째 행의 데이터를 가져와서 단계별로 분석
first_row = mama['data'].iloc[0]

# 1. 데이터 구조 출력
print("1. 데이터 구조:")
print("시작 부분:", first_row[:50])
print("끝 부분:", first_row[-50:])

# 2. result" 문자열 위치 확인
result_pos = first_row.find('result"')
print("\n2. 'result' 위치:", result_pos)

# 3. JSON 배열 시작/끝 위치 확인
array_start = first_row.find('[')
array_end = first_row.rfind(']')
print("\n3. JSON 배열 위치:")
print(f"배열 시작: {array_start}")
print(f"배열 끝: {array_end}")

# 4. 배열 내부의 첫 번째 객체 확인
if array_start != -1 and array_end != -1:
    first_object_end = first_row.find('}', array_start)
    if first_object_end != -1:
        print("\n4. 첫 번째 객체:")
        print(first_row[array_start:first_object_end+1])

# 5. 전체 구조를 더 명확하게 보기 위해 줄바꿈 추가
print("\n5. 구조화된 형태:")
structured = first_row.replace('},{', '},\n{')
print(structured[:200])
# Out:
# 1. 데이터 구조:
# 시작 부분: basePrice:3.66}]}"
# 끝 부분: basePrice:3.66}]}"
#
# 2. 'result' 위치: -1
#
# 3. JSON 배열 위치:
# 배열 시작: -1
# 배열 끝: 15
#
# 5. 구조화된 형태:
# basePrice:3.66}]}"

# %%
# 첫 번째 행의 데이터를 가져와서 단계별로 분석
first_row = mama['data'].iloc[0]

print("1. 데이터 구조:")
print("시작 부분:", first_row[:50])
print("끝 부분:", first_row[-50:])

# 2. result" 문자열 위치 확인
result_pos = first_row.find('result"')
print("\n2. 'result' 위치:", result_pos)

# 3. JSON 배열 시작/끝 위치 확인
array_start = first_row.find('[')
array_end = first_row.rfind(']')
print("\n3. JSON 배열 위치:")
print(f"배열 시작: {array_start}")
print(f"배열 끝: {array_end}")

# 4. 배열 내부의 첫 번째 객체 확인
if array_start != -1 and array_end != -1:
    first_object_end = first_row.find('}', array_start)
    if first_object_end != -1:
        print("\n4. 첫 번째 객체:")
        print(first_row[array_start:first_object_end+1])

# 5. 전체 구조를 더 명확하게 보기 위해 줄바꿈 추가
print("\n5. 구조화된 형태:")
structured = first_row.replace('},{', '},\n{')
print(structured[:200])

# 6. 문자열의 정확한 형태 확인을 위해 repr() 사용
print("\n6. 문자열의 정확한 형태:")
print(repr(first_row[:200]))
# Out:
# 1. 데이터 구조:
# 시작 부분: basePrice:3.66}]}"
# 끝 부분: basePrice:3.66}]}"
#
# 2. 'result' 위치: -1
#
# 3. JSON 배열 위치:
# 배열 시작: -1
# 배열 끝: 15
#
# 5. 구조화된 형태:
# basePrice:3.66}]}"
#
# 6. 문자열의 정확한 형태:
# 'basePrice:3.66}]}"'

# %%
df = pd.read_csv('../mama.csv', sep='\t')
# 원본 데이터 확인
print("데이터 타입:", type(df['data'].iloc[0]))
print("\n원본 데이터 일부:")
print(df['data'].iloc[0][:500])

# 데이터 전처리 과정 확인
cleaned_json = df['data'].iloc[0].strip('"')
print("\n전처리된 데이터 일부:")
print(cleaned_json[:500])

try:
    data = json.loads(cleaned_json)
    print("\n파싱 성공!")
    result_df = pd.DataFrame(data['result'])
    print(result_df)
except Exception as e:
    print("\n파싱 에러:", str(e))
# Out:
# 데이터 타입: <class 'str'>
#
# 원본 데이터 일부:
# {result":[{"cashSellingPrice":1447.23,"countryCode":"US","cashBuyingPrice":1498.77,"ttBuyingPrice":1458.6,"countryNameKr":"미국","currencyCode":"USD","ttSellingPrice":1487.4,"countryNameEn":"United States of America","currencyUnit":1,"basePrice":1473},{"cashSellingPrice":918.03,"countryCode":"JP","cashBuyingPrice":950.73,"ttBuyingPrice":925.23,"countryNameKr":"일본","currencyCode":"JPY","ttSellingPrice":943.53,"countryNameEn":"Japan","currencyUnit":100,"basePrice":934.38},{"cashSellingPrice":1481.66
#
# 전처리된 데이터 일부:
# {result":[{"cashSellingPrice":1447.23,"countryCode":"US","cashBuyingPrice":1498.77,"ttBuyingPrice":1458.6,"countryNameKr":"미국","currencyCode":"USD","ttSellingPrice":1487.4,"countryNameEn":"United States of America","currencyUnit":1,"basePrice":1473},{"cashSellingPrice":918.03,"countryCode":"JP","cashBuyingPrice":950.73,"ttBuyingPrice":925.23,"countryNameKr":"일본","currencyCode":"JPY","ttSellingPrice":943.53,"countryNameEn":"Japan","currencyUnit":100,"basePrice":934.38},{"cashSellingPrice":1481.66
#
# 파싱 에러: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)

# %%
# 탭으로 구분된 CSV 파일 읽기
df = pd.read_csv('../mama.csv', sep='\t')

# 데이터 확인
print("데이터프레임 형태:", df.shape)
print("\n컬럼명들:", df.columns.tolist())

# JSON 파싱 시도
import json

def parse_json(json_str):
    try:
        # 앞뒤 쌍따옴표 제거 후 파싱
        cleaned_json = json_str.strip('"')
        data = json.loads(cleaned_json)
        return pd.DataFrame(data['result'])
    except Exception as e:
        print("파싱 에러:", str(e))
        print("문제의 데이터:", json_str[:200])  # 처음 200자만 출력
        return None

# 첫 번째 행 파싱 시도
print("\n첫 번째 행 파싱 결과:")
first_row_data = parse_json(df['data'].iloc[0])
if first_row_data is not None:
    print(first_row_data)
# Out:
# 데이터프레임 형태: (17654, 1)
#
# 컬럼명들: ['data']
#
# 첫 번째 행 파싱 결과:
# 파싱 에러: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 문제의 데이터: {result":[{"cashSellingPrice":1447.23,"countryCode":"US","cashBuyingPrice":1498.77,"ttBuyingPrice":1458.6,"countryNameKr":"미국","currencyCode":"USD","ttSellingPrice":1487.4,"countryNameEn":"United Stat

# %%
# 탭으로 구분된 CSV 파일 읽기
df = pd.read_csv('../mama.csv', sep='\t')

# 데이터 형태 확인
print("데이터프레임 크기:", df.shape)
print("\n처음 몇 줄의 데이터:")
print(df.head(3))

# 첫 번째 행의 데이터만 자세히 살펴보기
print("\n첫 번째 행의 data 컬럼 내용:")
first_row = df['data'].iloc[0]
print(first_row[:500])  # 처음 500자만 출력

# 중복된 데이터인지 확인
print("\n유니크한 데이터 개수:", df['data'].nunique())
print("전체 데이터 개수:", len(df))
# Out:
# 데이터프레임 크기: (17654, 1)
#
# 처음 몇 줄의 데이터:
#                                                 data
# 0  {result":[{"cashSellingPrice":1447.23,"country...
# 1  {result":[{"cashSellingPrice":1447.23,"country...
# 2  {result":[{"cashSellingPrice":1447.23,"country...
#
# 첫 번째 행의 data 컬럼 내용:
# {result":[{"cashSellingPrice":1447.23,"countryCode":"US","cashBuyingPrice":1498.77,"ttBuyingPrice":1458.6,"countryNameKr":"미국","currencyCode":"USD","ttSellingPrice":1487.4,"countryNameEn":"United States of America","currencyUnit":1,"basePrice":1473},{"cashSellingPrice":918.03,"countryCode":"JP","cashBuyingPrice":950.73,"ttBuyingPrice":925.23,"countryNameKr":"일본","currencyCode":"JPY","ttSellingPrice":943.53,"countryNameEn":"Japan","currencyUnit":100,"basePrice":934.38},{"cashSellingPrice":1481.66
#
# 유니크한 데이터 개수: 5599
# 전체 데이터 개수: 17654

# %%
# 첫 번째 행의 데이터 자세히 확인
first_row = df['data'].iloc[0]
print("데이터 길이:", len(first_row))
print("\n처음 100자:")
print(first_row[:100])
print("\n마지막 100자:")
print(first_row[-100:])

# JSON 형식 검사
def check_json(json_str):
    # 중괄호 개수 확인
    open_braces = json_str.count('{')
    close_braces = json_str.count('}')
    print("\n중괄호 개수:")
    print(f"여는 중괄호: {open_braces}")
    print(f"닫는 중괄호: {close_braces}")
    
    # 대괄호 개수 확인
    open_brackets = json_str.count('[')
    close_brackets = json_str.count(']')
    print("\n대괄호 개수:")
    print(f"여는 대괄호: {open_brackets}")
    print(f"닫는 대괄호: {close_brackets}")

check_json(first_row)
# Out:
# 데이터 길이: 9242
#
# 처음 100자:
# {result":[{"cashSellingPrice":1447.23,"countryCode":"US","cashBuyingPrice":1498.77,"ttBuyingPrice":1
#
# 마지막 100자:
# encyCode":"HUF","ttSellingPrice":3.7,"countryNameEn":"Hungary","currencyUnit":1,"basePrice":3.66}]}"
#
# 중괄호 개수:
# 여는 중괄호: 43
# 닫는 중괄호: 43
#
# 대괄호 개수:
# 여는 대괄호: 1
# 닫는 대괄호: 1

# %%
# JSON 문자열 수정 및 파싱
def parse_json(json_str):
    try:
        # 1. JSON 형식 수정
        json_str = json_str.replace('{result":', '{"result":')
        
        # 2. 마지막 따옴표 처리
        if json_str.endswith('"}'):
            json_str = json_str[:-2] + '}'
            
        # 3. JSON 파싱
        data = json.loads(json_str)
        return pd.DataFrame(data['result'])
    except Exception as e:
        print("파싱 에러:", str(e))
        # 에러 발생 위치의 문자열 출력
        if hasattr(e, 'pos'):
            pos = e.pos
            print("문제 발생 부분:", json_str[max(0, pos-50):min(len(json_str), pos+50)])
        return None

# 첫 번째 행 파싱 시도
print("첫 번째 행 파싱 결과:")
first_row_data = parse_json(df['data'].iloc[0])

if first_row_data is not None:
    print("\n데이터 형태:", first_row_data.shape)
    print("\n처음 몇 개의 행:")
    print(first_row_data.head())
# Out:
# 첫 번째 행 파싱 결과:
# 파싱 에러: Extra data: line 1 column 9243 (char 9242)
# 문제 발생 부분: En":"Hungary","currencyUnit":1,"basePrice":3.66}]}"

# %% [markdown]
# ---
# # complete data preprocessing
# ---

# %%
df = pd.read_csv('../mama.csv', sep='\t', dtype=str)
# 칼럼 분리
df.columns = ['createdAt,data']  # 현재 하나의 칼럼명
df = df['createdAt,data'].str.split(',', n=1, expand=True)
df.columns = ['createdAt', 'data']
df
# Out:
#                  createdAt                                               data
# 0      2025-01-02 17:00:57  "{"result":[{"cashSellingPrice":1447.23,"count...
# 1      2025-01-02 17:05:09  "{"result":[{"cashSellingPrice":1447.23,"count...
# 2      2025-01-02 17:10:09  "{"result":[{"cashSellingPrice":1447.23,"count...
# 3      2025-01-02 17:15:09  "{"result":[{"cashSellingPrice":1447.23,"count...
# 4      2025-01-02 17:20:10  "{"result":[{"cashSellingPrice":1447.23,"count...
# ...                    ...                                                ...
# 17649  2025-01-31 23:50:10  "{"result":[{"cashSellingPrice":1432,"countryC...
# 17650  2025-01-31 23:52:09  "{"result":[{"cashSellingPrice":1432,"countryC...
# 17651  2025-01-31 23:54:09  "{"result":[{"cashSellingPrice":1432,"countryC...
# 17652  2025-01-31 23:56:09  "{"result":[{"cashSellingPrice":1432,"countryC...
# 17653  2025-01-31 23:58:09  "{"result":[{"cashSellingPrice":1432,"countryC...
#
# [17654 rows x 2 columns]

# %%
def parse_json(json_str, created_at=None):
    try:
        # 1. JSON 형식 수정
        json_str = json_str.replace('"{"result":', '{"result":')
        
        # 2. 마지막 부분 수정 (마지막 따옴표 제거)
        if json_str.endswith('}]}"'):
            json_str = json_str[:-1]  # 마지막 따옴표만 제거
            
        # 3. JSON 파싱
        data = json.loads(json_str)
        result_df = pd.DataFrame(data['result'])
        # 4. createdAt 컬럼 추가
        if created_at is not None:
            result_df['createdAt'] = created_at
        
        return result_df
    except Exception as e:
        print("파싱 에러:", str(e))
        return None

# 첫 번째 행 파싱 시도
print("첫 번째 행 파싱 결과:")
first_row_data = parse_json(df['data'].iloc[0])

if first_row_data is not None:
    print("\n데이터 형태:", first_row_data.shape)
    print("\n처음 몇 개의 행:")
    print(first_row_data[['countryNameKr', 'currencyCode', 'basePrice']].head())
# Out:
# 첫 번째 행 파싱 결과:
#
# 데이터 형태: (42, 10)
#
# 처음 몇 개의 행:
#   countryNameKr currencyCode  basePrice
# 0            미국          USD    1473.00
# 1            일본          JPY     934.38
# 2            유럽          EUR    1511.74
# 3            중국          CNY     200.63
# 4            홍콩          HKD     189.40

# %%
# 전체 데이터 처리
print(f"데이터 수: {len(df)}")

# 2. 모든 행의 JSON 데이터 파싱
parsed_data = []
for idx, row in df.iterrows():
    result = parse_json(row['data'], row['createdAt'])
    if result is not None:
        # createdAt 칼럼 한국 시간대로 변경
        result['createdAt'] = pd.to_datetime(result['createdAt'], format='%Y-%m-%d %H:%M:%S') + pd.Timedelta(hours=9)
        parsed_data.append(result)

# 3. 모든 파싱된 데이터를 하나의 데이터프레임으로 합치기
final_df = pd.concat(parsed_data, ignore_index=True)

# 4. 결과 확인
print("\n최종 데이터프레임 형태:", final_df.shape)
print("\n주요 통화 환율 추이:")
main_currencies = ['USD', 'JPY', 'EUR', 'CNY']
print(final_df[final_df['currencyCode'].isin(main_currencies)][['countryNameKr', 'currencyCode', 'basePrice', 'createdAt']].head(12))
# Out:
# 데이터 수: 17654
#
# 최종 데이터프레임 형태: (741384, 11)
#
# 주요 통화 환율 추이:
#    countryNameKr currencyCode  basePrice           createdAt
# 0             미국          USD    1473.00 2025-01-03 02:00:57
# 1             일본          JPY     934.38 2025-01-03 02:00:57
# 2             유럽          EUR    1511.74 2025-01-03 02:00:57
# 3             중국          CNY     200.63 2025-01-03 02:00:57
# 42            미국          USD    1473.00 2025-01-03 02:05:09
# 43            일본          JPY     934.38 2025-01-03 02:05:09
# 44            유럽          EUR    1511.74 2025-01-03 02:05:09
# 45            중국          CNY     200.63 2025-01-03 02:05:09
# 84            미국          USD    1473.00 2025-01-03 02:10:09
# 85            일본          JPY     934.38 2025-01-03 02:10:09
# 86            유럽          EUR    1511.74 2025-01-03 02:10:09
# 87            중국          CNY     200.63 2025-01-03 02:10:09

# %%
final_df
# Out:
#         cashSellingPrice countryCode  cashBuyingPrice  ttBuyingPrice  \
# 0                1447.23          US          1498.77        1458.60
# 1                 918.03          JP           950.73         925.23
# 2                1481.66          EU          1541.82        1496.63
# 3                 190.60          CN           210.66         198.63
# 4                 185.67          HK           193.13         187.51
# ...                  ...         ...              ...            ...
# 741379           4344.97          KW          5029.77        4675.57
# 741380              0.00          TR             0.00          40.22
# 741381              0.00          PK             0.00           0.00
# 741382            329.67          PL           386.99         354.39
# 741383              3.42          HU             4.05           3.67
#
#        countryNameKr currencyCode  ttSellingPrice             countryNameEn  \
# 0                 미국          USD         1487.40  United States of America
# 1                 일본          JPY          943.53                     Japan
# 2                 유럽          EUR         1526.85                    Europe
# 3                 중국          CNY          202.63                     China
# 4                 홍콩          HKD          191.29                 Hong Kong
# ...              ...          ...             ...                       ...
# 741379          쿠웨이트          KWD         4770.01                    Kuwait
# 741380            터키          TRY           41.10                    Turkey
# 741381          파키스탄          PKR            0.00                  Pakistan
# 741382           폴란드          PLN          362.27                    Poland
# 741383           헝가리          HUF            3.75                   Hungary
#
#         currencyUnit  basePrice           createdAt
# 0                  1    1473.00 2025-01-03 02:00:57
# 1                100     934.38 2025-01-03 02:00:57
# 2                  1    1511.74 2025-01-03 02:00:57
# 3                  1     200.63 2025-01-03 02:00:57
# 4                  1     189.40 2025-01-03 02:00:57
# ...              ...        ...                 ...
# 741379             1    4722.79 2025-02-01 08:58:09
# 741380             1      40.66 2025-02-01 08:58:09
# 741381             1       5.23 2025-02-01 08:58:09
# 741382             1     358.33 2025-02-01 08:58:09
# 741383             1       3.71 2025-02-01 08:58:09
#
# [741384 rows x 11 columns]

# %%
final_df['currencyCode'].unique()
# Out:
# array(['USD', 'JPY', 'EUR', 'CNY', 'HKD', 'THB', 'TWD', 'PHP', 'SGD',
#        'AUD', 'VND', 'GBP', 'CAD', 'MYR', 'RUB', 'ZAR', 'NOK', 'NZD',
#        'DKK', 'MXN', 'MNT', 'BHD', 'BDT', 'BRL', 'BND', 'SAR', 'SEK',
#        'CHF', 'AED', 'JOD', 'ILS', 'EGP', 'INR', 'IDR', 'CZK', 'KZT',
#        'QAR', 'KWD', 'TRY', 'PKR', 'PLN', 'HUF'], dtype=object)

# %%
curr = ['USD', 'JPY', 'CNY', 'CAD']
filtered_df = final_df[final_df['currencyCode'].isin(curr)]
filtered_df['currencyCode'].unique()
# Out:
# array(['USD', 'JPY', 'CNY', 'CAD'], dtype=object)

# %%
filtered_df
# Out:
#         cashSellingPrice countryCode  cashBuyingPrice  ttBuyingPrice  \
# 0                1447.23          US          1498.77        1458.60
# 1                 918.03          JP           950.73         925.23
# 3                 190.60          CN           210.66         198.63
# 12               1001.07          CA          1041.29        1010.97
# 42               1447.23          US          1498.77        1458.60
# ...                  ...         ...              ...            ...
# 741312            984.05          CA          1023.59         993.79
# 741342           1432.00          US          1483.00        1443.30
# 741343            922.92          JP           955.78         930.15
# 741345            189.30          CN           209.22         197.27
# 741354            984.05          CA          1023.59         993.79
#
#        countryNameKr currencyCode  ttSellingPrice             countryNameEn  \
# 0                 미국          USD         1487.40  United States of America
# 1                 일본          JPY          943.53                     Japan
# 3                 중국          CNY          202.63                     China
# 12               캐나다          CAD         1031.39                    Canada
# 42                미국          USD         1487.40  United States of America
# ...              ...          ...             ...                       ...
# 741312           캐나다          CAD         1013.85                    Canada
# 741342            미국          USD         1471.70  United States of America
# 741343            일본          JPY          948.55                     Japan
# 741345            중국          CNY          201.25                     China
# 741354           캐나다          CAD         1013.85                    Canada
#
#         currencyUnit  basePrice           createdAt
# 0                  1    1473.00 2025-01-03 02:00:57
# 1                100     934.38 2025-01-03 02:00:57
# 3                  1     200.63 2025-01-03 02:00:57
# 12                 1    1021.18 2025-01-03 02:00:57
# 42                 1    1473.00 2025-01-03 02:05:09
# ...              ...        ...                 ...
# 741312             1    1003.82 2025-02-01 08:56:09
# 741342             1    1457.50 2025-02-01 08:58:09
# 741343           100     939.35 2025-02-01 08:58:09
# 741345             1     199.26 2025-02-01 08:58:09
# 741354             1    1003.82 2025-02-01 08:58:09
#
# [70613 rows x 11 columns]

# %%
trade = pd.read_csv('../trade.csv')
trade.head(10)
# Out:
#    isBuyOrder currencyCode    amount   price           executedAt  \
# 0           1          JPY   27403.0  938.80  2025-01-01 00:33:24
# 1           1          JPY   27129.0  938.80  2025-01-01 00:35:23
# 2           1          JPY   26858.0  938.80  2025-01-01 00:47:06
# 3           1          JPY   26589.0  938.80  2025-01-01 00:50:28
# 4           1          JPY   26323.0  938.80  2025-01-01 01:00:54
# 5           1          JPY   26060.0  938.80  2025-01-01 02:23:34
# 6           0          KRW  250000.0  938.82  2025-01-01 02:28:34
# 7           0          KRW  170000.0  938.82  2025-01-01 02:29:06
# 8           0          KRW  100000.0  938.82  2025-01-01 02:33:27
# 9           0          KRW  100000.0  938.82  2025-01-01 02:34:15
#
#   currencyCode0
# 0           JPY
# 1           JPY
# 2           JPY
# 3           JPY
# 4           JPY
# 5           JPY
# 6           JPY
# 7           JPY
# 8           JPY
# 9           JPY

# %%
trade.describe()
# Out:
#         isBuyOrder         amount        price
# count  2454.000000    2454.000000  2454.000000
# mean      0.563570   17564.598615  1139.090024
# std       0.496044   33459.533392   273.510359
# min       0.000000       1.000000   197.870000
# 25%       0.000000     735.250000   924.180000
# 50%       1.000000   10000.000000   935.050000
# 75%       1.000000   24110.500000  1458.200000
# max       1.000000  500000.000000  1477.100000

# %%
krw = trade[trade['currencyCode'] == 'KRW']
krw.head()
# Out:
#     isBuyOrder currencyCode    amount   price           executedAt  \
# 6            0          KRW  250000.0  938.82  2025-01-01 02:28:34
# 7            0          KRW  170000.0  938.82  2025-01-01 02:29:06
# 8            0          KRW  100000.0  938.82  2025-01-01 02:33:27
# 9            0          KRW  100000.0  938.82  2025-01-01 02:34:15
# 10           0          KRW  100000.0  938.82  2025-01-01 02:37:26
#
#    currencyCode0
# 6            JPY
# 7            JPY
# 8            JPY
# 9            JPY
# 10           JPY

# %% [markdown]
# ---
# 1. isBuyOrder = 1 일 때, price -1 이 등장하는가?
# 2. isBuyOrder = 0 일 때, price +1 이 등장하는가?
# ---

# %%
# 매수 주문 필터링
buy = trade[trade['isBuyOrder'] == 1]

# 매수 주문에 대해 등장 여부 확인
matches = 0

for _, order in buy.iterrows():
    # 동일한 통화 / price +1
    match_count = filtered_df[
        (filtered_df['currencyCode'] == order['currencyCode']) &
        (filtered_df['basePrice'] == order['price'] + 1)
    ].shape[0]
    matches +=match_count

print(f'매수 주문 등장 횟수 : {matches}')
# Out:
# 매수 주문 등장 횟수 : 29864

# %%
# 더 자세한 분석을 위해 통화별로 확인
print("\n통화별 매칭 횟수:")
for currency in filtered_df['currencyCode'].unique():
    currency_buy_orders = buy[buy['currencyCode'] == currency]
    currency_matches = 0
    
    for _, order in currency_buy_orders.iterrows():
        match_count = filtered_df[
            (filtered_df['currencyCode'] == currency) & 
            (filtered_df['basePrice'] == order['price'] + 1)
        ].shape[0]
        currency_matches += match_count
    
    print(f"{currency}: {currency_matches}회")
# Out:
# 통화별 매칭 횟수:
# USD: 18258회
# JPY: 11407회
# CNY: 167회
# CAD: 32회

# %%
# 결과를 저장할 리스트 초기화
results = []

# trade의 각 행을 순회
for idx, trade_row in trade.iterrows():
    # KRW인 경우 currencyCode0 사용
    currency = trade_row['currencyCode0'] if trade_row['currencyCode'] == 'KRW' else trade_row['currencyCode']
    trade_row['executedAt'] = pd.to_datetime(trade_row['executedAt'], format='%Y-%m-%d %H:%M:%S') + pd.Timedelta(hours=9)
    # 매수 /매도에 다라 target_price 계산
    if trade_row['isBuyOrder'] == 1: # 매수
        target_price = trade_row['price'] - 1
    else: # 매도
        target_price = trade_row['price'] + 1
        # target price가 filtered_df에 존재하는지 확인
        matches = filtered_df[
            (filtered_df['currencyCode'] == currency) & 
            (filtered_df['basePrice'] == target_price)
        ].shape[0]

    
    results.append({
        'currency': currency,
        'order_type' : '매수' if trade_row['isBuyOrder'] == 1 else '매도',
        'original_price': trade_row['price'],
        'target_price': target_price,
        'found': matches > 0,
        'match_count': matches,
        'createdAt' : trade_row['executedAt']
    })

# 결과를 데이터프레임으로 변환
results_df = pd.DataFrame(results)

# 결과 요약
print("전체 거래 수:", len(results))
print("목표가가 등장한 거래 수:", results_df['found'].sum())

print("\n주문 유형별 매칭 결과:")
print(results_df.groupby('order_type')[['found']].sum())

print("\n통화별 매칭 결과:")
print(results_df.groupby('currency')[['found']].sum())

print("\n통화 및 주문 유형별 매칭 결과:")
print(results_df.groupby(['currency', 'order_type'])[['found']].sum())

# 전체 결과 확인
print("\n처음 10개 거래 상세 결과:")
results_df.head(10)
# Out:
# 전체 거래 수: 2454
# 목표가가 등장한 거래 수: 2187
#
# 주문 유형별 매칭 결과:
#             found
# order_type
# 매도            973
# 매수           1214
#
# 통화별 매칭 결과:
#           found
# currency
# CAD          43
# CNY          13
# JPY        1189
# USD         942
#
# 통화 및 주문 유형별 매칭 결과:
#                      found
# currency order_type
# CAD      매도             34
#          매수              9
# CNY      매도              3
#          매수             10
# JPY      매도            444
#          매수            745
# USD      매도            492
#          매수            450
#
# 처음 10개 거래 상세 결과:
#   currency order_type  original_price  target_price  found  match_count  \
# 0      JPY         매수          938.80        937.80   True           61
# 1      JPY         매수          938.80        937.80   True           61
# 2      JPY         매수          938.80        937.80   True           61
# 3      JPY         매수          938.80        937.80   True           61
# 4      JPY         매수          938.80        937.80   True           61
# 5      JPY         매수          938.80        937.80   True           61
# 6      JPY         매도          938.82        939.82   True            1
# 7      JPY         매도          938.82        939.82   True            1
# 8      JPY         매도          938.82        939.82   True            1
# 9      JPY         매도          938.82        939.82   True            1
#
#             createdAt
# 0 2025-01-01 09:33:24
# 1 2025-01-01 09:35:23
# 2 2025-01-01 09:47:06
# 3 2025-01-01 09:50:28
# 4 2025-01-01 10:00:54
# 5 2025-01-01 11:23:34
# 6 2025-01-01 11:28:34
# 7 2025-01-01 11:29:06
# 8 2025-01-01 11:33:27
# 9 2025-01-01 11:34:15

# %%
import yfinance as yf

data = yf.download('USDKRW=X', start='2024-11-01', end='2024-12-30')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open   Volume
# Ticker         USDKRW=X     USDKRW=X     USDKRW=X     USDKRW=X USDKRW=X
# Date
# 2024-11-01  1372.930054  1380.229980  1372.520020  1372.930054        0
# 2024-11-04  1379.339966  1376.020020  1367.780029  1379.339966        0
# 2024-11-05  1372.859985  1380.569946  1372.640015  1372.859985        0
# 2024-11-06  1378.000000  1403.969971  1345.760010  1378.000000        0
# 2024-11-07  1399.800049  1404.030029  1381.020020  1399.800049        0
# 2024-11-08  1372.079956  1397.369995  1372.079956  1372.079956        0
# 2024-11-11  1397.199951  1402.000000  1391.930054  1397.199951        0
# 2024-11-12  1400.550049  1409.550049  1398.560059  1400.550049        0
# 2024-11-13  1406.650024  1410.540039  1391.410034  1406.650024        0
# 2024-11-14  1399.000000  1411.270020  1386.160034  1399.000000        0
# 2024-11-15  1400.829956  1408.380005  1389.239990  1400.829956        0
# 2024-11-18  1394.349976  1400.329956  1389.260010  1394.349976        0
# 2024-11-19  1389.500000  1397.150024  1388.250000  1389.500000        0
# 2024-11-20  1392.160034  1400.910034  1388.000000  1392.160034        0
# 2024-11-21  1397.619995  1402.130005  1393.829956  1397.619995        0
# 2024-11-22  1399.599976  1408.189941  1398.300049  1399.599976        0
# 2024-11-25  1403.510010  1404.329956  1395.089966  1403.510010        0
# 2024-11-26  1395.560059  1407.569946  1393.479980  1395.560059        0
# 2024-11-27  1395.270020  1398.449951  1389.369995  1395.270020        0
# 2024-11-28  1388.469971  1397.569946  1388.469971  1388.469971        0
# 2024-11-29  1393.300049  1398.500000  1389.650024  1393.300049        0
# 2024-12-02  1399.859985  1407.050049  1397.949951  1399.859985        0
# 2024-12-03  1401.060059  1442.209961  1375.040039  1401.060059        0
# 2024-12-04  1411.670044  1418.280029  1403.510010  1411.670044        0
# 2024-12-05  1410.800049  1419.069946  1410.930054  1410.800049        0
# 2024-12-06  1399.989990  1427.969971  1411.359985  1399.989990        0
# 2024-12-09  1424.219971  1438.239990  1424.260010  1424.219971        0
# 2024-12-10  1426.599976  1433.170044  1425.290039  1426.599976        0
# 2024-12-11  1433.949951  1435.949951  1418.619995  1433.949951        0
# 2024-12-12  1429.150024  1434.589966  1427.810059  1429.150024        0
# 2024-12-13  1427.859985  1436.000000  1428.760010  1427.859985        0
# 2024-12-16  1434.449951  1438.859985  1432.969971  1434.449951        0
# 2024-12-17  1431.349976  1439.500000  1433.969971  1431.349976        0
# 2024-12-18  1436.420044  1438.640015  1433.790039  1436.420044        0
# 2024-12-19  1451.500000  1453.060059  1436.219971  1451.500000        0
# 2024-12-20  1437.449951  1452.000000  1440.109985  1437.449951        0
# 2024-12-23  1445.420044  1453.520020  1445.430054  1445.420044        0
# 2024-12-24  1442.699951  1459.920044  1449.329956  1442.699951        0
# 2024-12-25  1453.420044  1458.079956  1448.449951  1453.420044        0
# 2024-12-26  1457.609985  1470.290039  1454.770020  1457.609985        0
# 2024-12-27  1466.989990  1487.040039  1462.800049  1466.989990        0

# %%
start_date = '2024-08-01'
end_date = '2025-02-28'
# ✅ 데이터 다운로드 함수
def get_yfinance_data(ticker, start_date, end_date):
    data = yf.download(ticker, start=start_date, end=end_date, interval="1h")
    if isinstance(data, pd.DataFrame):
        return data[['Open', 'High', 'Low', 'Close']] if 'Open' in data.columns else data[['Close']]
    else:
        raise ValueError(f"Data for {ticker} is not a DataFrame. Got {type(data)}.")

# ✅ 1. USD/KRW 환율 데이터 가져오기
usd_krw = get_yfinance_data("USDKRW=X", start_date, end_date)

# ✅ 2. 금 가격 (Gold Futures) 가져오기
jpy_krw = get_yfinance_data("JPYKRW=X", start_date, end_date)

# ✅ 3. 원유 가격 (Crude Oil Futures) 가져오기
cad_krw = get_yfinance_data("CADKRW=X", start_date, end_date)


# ✅ 컬럼명 변경 (구분하기 쉽게)
usd_krw.columns = ['usd_krw_open', 'usd_krw_high', 'usd_krw_low', 'usd_krw_close']
jpy_krw.columns = ['jpy_krw_open', 'jpy_krw_high', 'jpy_krw_low', 'jpy_krw_close']
cad_krw.columns = ['cad_krw_open', 'cad_krw_high', 'cad_krw_low', 'cad_krw_close']

# ✅ 날짜 인덱스를 기준으로 병합 (merge 사용)
df = usd_krw.merge(jpy_krw, how='outer', left_index=True, right_index=True)
df = df.merge(cad_krw, how='outer', left_index=True, right_index=True)
df.reset_index(inplace=True)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                       Datetime  usd_krw_open  usd_krw_high  usd_krw_low  \
# 0    2024-08-01 00:00:00+00:00   1367.569946   1369.380005  1365.709961
# 1    2024-08-01 01:00:00+00:00   1368.719971   1369.000000  1364.300049
# 2    2024-08-01 02:00:00+00:00   1367.489990   1368.079956  1363.250000
# 3    2024-08-01 03:00:00+00:00   1365.239990   1366.089966  1361.229980
# 4    2024-08-01 04:00:00+00:00   1363.069946   1363.810059  1360.969971
# ...                        ...           ...           ...          ...
# 3280 2025-02-18 21:00:00+00:00   1440.219971   1441.150024  1439.479980
# 3281 2025-02-18 22:00:00+00:00   1440.689941   1440.689941  1439.579956
# 3282 2025-02-19 00:00:00+00:00   1440.560059   1443.380005  1439.640015
# 3283 2025-02-19 01:00:00+00:00   1441.239990   1442.280029  1437.189941
# 3284 2025-02-19 02:00:00+00:00   1440.329956   1441.489990  1439.609985
#
#       usd_krw_close  jpy_krw_open  jpy_krw_high  jpy_krw_low  jpy_krw_close  \
# 0       1368.709961         9.116         9.139        9.114          9.139
# 1       1367.479980         9.141         9.166        9.141          9.150
# 2       1365.280029         9.149         9.149        9.099          9.099
# 3       1363.099976         9.102         9.110        9.090          9.090
# 4       1363.650024         9.095         9.103        9.085          9.087
# ...             ...           ...           ...          ...            ...
# 3280    1440.680054         9.452         9.458        9.445          9.445
# 3281    1440.560059         9.454         9.455        9.447          9.452
# 3282    1441.250000         9.469         9.473        9.458          9.463
# 3283    1440.329956         9.460         9.465        9.443          9.453
# 3284    1440.869995         9.450         9.453        9.443          9.448
#
#       cad_krw_open  cad_krw_high  cad_krw_low  cad_krw_close
# 0       990.489990    991.640015   990.489990     991.229980
# 1       991.070007    991.070007   989.309998     989.530029
# 2       990.030029    990.030029   989.049988     989.390015
# 3       989.739990    989.739990   987.289978     987.330017
# 4       987.489990    987.739990   986.940002     987.539978
# ...            ...           ...          ...            ...
# 3280   1015.130005   1016.020020  1014.479980    1014.479980
# 3281   1015.349976   1015.349976  1014.210022    1015.049988
# 3282   1015.510010   1016.260010  1014.859985    1016.059998
# 3283   1015.859985   1015.859985  1013.250000    1015.469971
# 3284   1015.619995   1015.859985  1015.530029    1015.580017
#
# [3285 rows x 13 columns]

# %%
# ✅ 3. 데이터를 melt하여 통화별 데이터를 통합
melted_df = pd.melt(
    df,
    id_vars=['Datetime'],
    value_vars=[
        'usd_krw_open', 'usd_krw_high', 'usd_krw_low', 'usd_krw_close',
        'jpy_krw_open', 'jpy_krw_high', 'jpy_krw_low', 'jpy_krw_close',
        'cad_krw_open', 'cad_krw_high', 'cad_krw_low', 'cad_krw_close'
    ],
    var_name='metric',
    value_name='value'
)

# ✅ 4. 'metric'에서 통화 코드와 가격 종류(open, high, low, close) 분리
melted_df['currencyCode'] = melted_df['metric'].apply(lambda x: x.split('_')[0].upper())
melted_df['priceType'] = melted_df['metric'].apply(lambda x: x.split('_')[-1].lower())

# ✅ 5. 'metric' 열 삭제
melted_df.drop(columns=['metric'], inplace=True)

# ✅ 6. 피벗(pivot)하여 하나의 행에 고가, 저가, 오픈, 종가 정보가 들어가도록 변환
final_df = melted_df.pivot_table(
    index=['Datetime', 'currencyCode'],
    columns='priceType',
    values='value'
).reset_index()

# ✅ 컬럼 정리
final_df.columns.name = None  # 컬럼명 정리
final_df = final_df[['Datetime', 'currencyCode', 'high', 'low', 'open', 'close']]

# ✅ 결과 출력
print(final_df.head(10))
# Out:
#                    Datetime currencyCode         high          low  \
# 0 2024-08-01 00:00:00+00:00          CAD   991.640015   990.489990
# 1 2024-08-01 00:00:00+00:00          JPY     9.139000     9.114000
# 2 2024-08-01 00:00:00+00:00          USD  1369.380005  1365.709961
# 3 2024-08-01 01:00:00+00:00          CAD   991.070007   989.309998
# 4 2024-08-01 01:00:00+00:00          JPY     9.166000     9.141000
# 5 2024-08-01 01:00:00+00:00          USD  1369.000000  1364.300049
# 6 2024-08-01 02:00:00+00:00          CAD   990.030029   989.049988
# 7 2024-08-01 02:00:00+00:00          JPY     9.149000     9.099000
# 8 2024-08-01 02:00:00+00:00          USD  1368.079956  1363.250000
# 9 2024-08-01 03:00:00+00:00          CAD   989.739990   987.289978
#
#           open        close
# 0   990.489990   991.229980
# 1     9.116000     9.139000
# 2  1367.569946  1368.709961
# 3   991.070007   989.530029
# 4     9.141000     9.150000
# 5  1368.719971  1367.479980
# 6   990.030029   989.390015
# 7     9.149000     9.099000
# 8  1367.489990  1365.280029
# 9   989.739990   987.330017

# %%
def load_yahoo_data(currencies, start_date, end_date):
    """
    야후 파이낸스에서 통화 데이터를 다운로드합니다.
    """
    data_frames = []
    for currency in currencies:
        # 통화 코드 형식: "USDKRW=X", "JPYKRW=X" 등의 형태로 설정
        ticker = f'{currency}KRW=X'
        df = yf.download(ticker, start=start_date, end=end_date)
        df['currency'] = currency
        df.reset_index(inplace=True)
        df.rename(columns={
            'Date': 'createdAt',
            'High': 'highPrice',
            'Low': 'lowPrice',
            'Close': 'closePrice'
        }, inplace=True)
        data_frames.append(df)
    return pd.concat(data_frames, ignore_index=True)

# %%
import pandas as pd
available_currencies = ['USD', 'JPY', 'CNY', 'CAD']
# 설정: 2024-08 ~ 2025-02
start_date = '2024-08-01'
end_date = '2025-02-28'
# 야후 파이낸스 데이터 로드
final_df = load_yahoo_data(available_currencies, start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
final_df
# Out:
# Price   createdAt   closePrice    highPrice     lowPrice         Open  \
# Ticker                USDKRW=X     USDKRW=X     USDKRW=X     USDKRW=X
# 0      2024-08-01  1367.920044  1369.369995  1360.859985  1367.920044
# 1      2024-08-02  1368.969971  1376.969971  1350.989990  1368.969971
# 2      2024-08-05  1357.170044  1374.329956  1353.979980  1357.170044
# 3      2024-08-06  1367.400024  1379.660034  1364.079956  1367.400024
# 4      2024-08-07  1370.310059  1378.949951  1372.180054  1370.310059
# ..            ...          ...          ...          ...          ...
# 428    2025-02-13          NaN          NaN          NaN          NaN
# 429    2025-02-14          NaN          NaN          NaN          NaN
# 430    2025-02-17          NaN          NaN          NaN          NaN
# 431    2025-02-18          NaN          NaN          NaN          NaN
# 432    2025-02-19          NaN          NaN          NaN          NaN
#
# Price    Volume currency closePrice highPrice lowPrice  ... closePrice  \
# Ticker USDKRW=X            JPYKRW=X  JPYKRW=X JPYKRW=X  ...   CNYKRW=X
# 0           0.0      USD        NaN       NaN      NaN  ...        NaN
# 1           0.0      USD        NaN       NaN      NaN  ...        NaN
# 2           0.0      USD        NaN       NaN      NaN  ...        NaN
# 3           0.0      USD        NaN       NaN      NaN  ...        NaN
# 4           0.0      USD        NaN       NaN      NaN  ...        NaN
# ..          ...      ...        ...       ...      ...  ...        ...
# 428         NaN      CAD        NaN       NaN      NaN  ...        NaN
# 429         NaN      CAD        NaN       NaN      NaN  ...        NaN
# 430         NaN      CAD        NaN       NaN      NaN  ...        NaN
# 431         NaN      CAD        NaN       NaN      NaN  ...        NaN
# 432         NaN      CAD        NaN       NaN      NaN  ...        NaN
#
# Price  highPrice lowPrice     Open   Volume   closePrice    highPrice  \
# Ticker  CNYKRW=X CNYKRW=X CNYKRW=X CNYKRW=X     CADKRW=X     CADKRW=X
# 0            NaN      NaN      NaN      NaN          NaN          NaN
# 1            NaN      NaN      NaN      NaN          NaN          NaN
# 2            NaN      NaN      NaN      NaN          NaN          NaN
# 3            NaN      NaN      NaN      NaN          NaN          NaN
# 4            NaN      NaN      NaN      NaN          NaN          NaN
# ..           ...      ...      ...      ...          ...          ...
# 428          NaN      NaN      NaN      NaN  1015.386902  1018.460327
# 429          NaN      NaN      NaN      NaN  1013.862976  1018.379517
# 430          NaN      NaN      NaN      NaN  1014.622681  1018.270508
# 431          NaN      NaN      NaN      NaN  1015.991089  1018.063721
# 432          NaN      NaN      NaN      NaN  1015.859985  1016.260010
#
# Price      lowPrice         Open   Volume
# Ticker     CADKRW=X     CADKRW=X CADKRW=X
# 0               NaN          NaN      NaN
# 1               NaN          NaN      NaN
# 2               NaN          NaN      NaN
# 3               NaN          NaN      NaN
# 4               NaN          NaN      NaN
# ..              ...          ...      ...
# 428     1012.576355  1015.590088      0.0
# 429     1012.925049  1013.877319      0.0
# 430     1014.908875  1014.944641      0.0
# 431     1013.016357  1016.026855      0.0
# 432     1013.250000  1015.510010      0.0
#
# [433 rows x 22 columns]

# %%
# 데이터프레임의 열 이름 출력
final_df.columns.tolist()
# Out:
# [('createdAt', ''),
#  ('closePrice', 'USDKRW=X'),
#  ('highPrice', 'USDKRW=X'),
#  ('lowPrice', 'USDKRW=X'),
#  ('Open', 'USDKRW=X'),
#  ('Volume', 'USDKRW=X'),
#  ('currency', ''),
#  ('closePrice', 'JPYKRW=X'),
#  ('highPrice', 'JPYKRW=X'),
#  ('lowPrice', 'JPYKRW=X'),
#  ('Open', 'JPYKRW=X'),
#  ('Volume', 'JPYKRW=X'),
#  ('closePrice', 'CNYKRW=X'),
#  ('highPrice', 'CNYKRW=X'),
#  ('lowPrice', 'CNYKRW=X'),
#  ('Open', 'CNYKRW=X'),
#  ('Volume', 'CNYKRW=X'),
#  ('closePrice', 'CADKRW=X'),
#  ('highPrice', 'CADKRW=X'),
#  ('lowPrice', 'CADKRW=X'),
#  ('Open', 'CADKRW=X'),
#  ('Volume', 'CADKRW=X')]

# %%
import yfinance as yf
import pandas as pd

def get_currency_data(currencies, start_date, end_date):
    data_frames = []

    for currency in currencies:
        ticker = f"{currency}KRW=X"
        data = yf.download(ticker, start=start_date, end=end_date)

        if isinstance(data, pd.DataFrame):
            data = data[['Open', 'High', 'Low', 'Close']] if 'Open' in data.columns else data[['Close']]
            data.columns = [f"{currency.lower()}_krw_open", f"{currency.lower()}_krw_high",
                            f"{currency.lower()}_krw_low", f"{currency.lower()}_krw_close"]
            data.reset_index(inplace=True)  # Datetime을 인덱스에서 열로 변환
            data_frames.append(data)
        else:
            raise ValueError(f"Data for {ticker} is not a DataFrame. Got {type(data)}.")

    # 병합
    merged_df = pd.concat(data_frames, axis=1)

    # ✅ 'Datetime' 열이 중복될 수 있으므로 병합 후 하나로 통일
    merged_df = merged_df.loc[:, ~merged_df.columns.duplicated()]
    merged_df['Date'] = pd.to_datetime(merged_df['Date']).dt.strftime('%Y-%m-%d')
    # 데이터 melt
    melted_df = pd.melt(
        merged_df,
        id_vars=['Date'],
        value_vars=[col for col in merged_df.columns if col != 'Date'],
        var_name='metric',
        value_name='value'
    )

    # 통화 코드 및 가격 타입 추출
    melted_df['currencyCode'] = melted_df['metric'].apply(lambda x: x.split('_')[0].upper())
    melted_df['priceType'] = melted_df['metric'].apply(lambda x: x.split('_')[-1].lower())

    # ✅ JPY 데이터만 100을 곱함
    melted_df.loc[melted_df['currencyCode'] == 'JPY', 'value'] *= 100

    # ✅ 모든 값 소수점 둘째 자리까지 표시
    melted_df['value'] = melted_df['value'].round(2)

    # 피벗하여 최종 데이터 프레임 생성
    final_df = melted_df.pivot_table(
        index=['Date', 'currencyCode'],
        columns='priceType',
        values='value'
    ).reset_index()

    # 컬럼 정리
    final_df.columns.name = None
    final_df = final_df[['Date', 'currencyCode', 'high', 'low', 'open', 'close']]

    return final_df

# ✅ 함수 사용 예제
start_date = '2024-08-01'
end_date = '2025-02-19'
currencies = ['USD', 'JPY', 'CAD']

currency_data = get_currency_data(currencies, start_date, end_date)
print(currency_data.tail(10))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#            Date currencyCode     high      low     open    close
# 419  2025-02-13          USD  1454.95  1444.61  1452.12  1452.12
# 420  2025-02-14          CAD  1018.38  1012.93  1013.88  1013.86
# 421  2025-02-14          JPY   946.89   940.32   940.55   940.51
# 422  2025-02-14          USD  1445.01  1434.65  1438.74  1438.74
# 423  2025-02-17          CAD  1018.27  1014.91  1014.94  1014.62
# 424  2025-02-17          JPY   953.20   946.41   946.88   946.64
# 425  2025-02-17          USD  1444.75  1438.71  1432.60  1432.60
# 426  2025-02-18          CAD  1018.06  1013.02  1016.03  1015.99
# 427  2025-02-18          JPY   953.03   947.13   951.72   951.66
# 428  2025-02-18          USD  1445.89  1437.51  1441.29  1441.29

# %%
currency_data.to_csv('../yh.csv', index=False)

# %%
final_df = pd.read_csv('../yh.csv')

# %%
final_df
# Out:
#            Date currencyCode     high      low     open    close
# 0    2024-08-01          CAD   991.64   985.64   990.61   990.64
# 1    2024-08-01          JPY   919.66   904.52   913.43   913.47
# 2    2024-08-01          USD  1369.37  1360.86  1367.92  1367.92
# 3    2024-08-02          CAD   992.35   974.53   986.21   986.24
# 4    2024-08-02          JPY   926.90   913.66   917.55   917.43
# ..          ...          ...      ...      ...      ...      ...
# 424  2025-02-17          JPY   953.20   946.41   946.88   946.64
# 425  2025-02-17          USD  1444.75  1438.71  1432.60  1432.60
# 426  2025-02-18          CAD  1018.06  1013.02  1016.03  1015.99
# 427  2025-02-18          JPY   953.03   947.13   951.72   951.66
# 428  2025-02-18          USD  1445.89  1437.51  1441.29  1441.29
#
# [429 rows x 6 columns]

# %%
def load_trade_data():
    # 거래 데이터 로드
    trade_df = pd.read_csv('../trade_08_02.csv')
    trade_df['executedAt'] = pd.to_datetime(trade_df['executedAt'], format='%Y-%m-%d %H:%M:%S') + pd.Timedelta(hours=9) # UTC -> KST
    
    return trade_df

def load_yh_data():
    # 야후 데이터 로드 
    final_df = pd.read_csv('../yh.csv')
    final_df['Date'] = pd.to_datetime(final_df['Date'], format='%Y-%m-%d') + pd.Timedelta(hours=9) # UTC -> KST

    return final_df

# %%
trade_df = load_trade_data()
final_df = load_yh_data()

# %%
trade_df
# Out:
#        isBuyOrder currencyCode   amount    price          executedAt
# 0               0          KRW   1000.0  1367.71 2024-08-01 09:09:11
# 1               1          USD   1000.0  1368.89 2024-08-01 09:18:57
# 2               1          USD     10.0  1368.99 2024-08-01 10:14:30
# 3               0          KRW   3000.0  1366.61 2024-08-01 10:35:10
# 4               0          KRW    800.0  1366.61 2024-08-01 10:40:03
# ...           ...          ...      ...      ...                 ...
# 17903           0          JPY  97130.0   948.14 2025-02-19 08:57:51
# 17904           0          JPY  38286.0   949.10 2025-02-19 09:00:28
# 17905           0          JPY  70000.0   950.04 2025-02-19 09:13:14
# 17906           0          JPY  30000.0   950.04 2025-02-19 09:14:03
# 17907           0          JPY   1714.0   948.87 2025-02-19 09:26:04
#
# [17908 rows x 5 columns]

# %%
final_df
# Out:
#                    Date currencyCode     high      low     open    close
# 0   2024-08-01 09:00:00          CAD   991.64   985.64   990.61   990.64
# 1   2024-08-01 09:00:00          JPY   919.66   904.52   913.43   913.47
# 2   2024-08-01 09:00:00          USD  1369.37  1360.86  1367.92  1367.92
# 3   2024-08-02 09:00:00          CAD   992.35   974.53   986.21   986.24
# 4   2024-08-02 09:00:00          JPY   926.90   913.66   917.55   917.43
# ..                  ...          ...      ...      ...      ...      ...
# 424 2025-02-17 09:00:00          JPY   953.20   946.41   946.88   946.64
# 425 2025-02-17 09:00:00          USD  1444.75  1438.71  1432.60  1432.60
# 426 2025-02-18 09:00:00          CAD  1018.06  1013.02  1016.03  1015.99
# 427 2025-02-18 09:00:00          JPY   953.03   947.13   951.72   951.66
# 428 2025-02-18 09:00:00          USD  1445.89  1437.51  1441.29  1441.29
#
# [429 rows x 6 columns]

# %%
# 지정한 값
threshold = 1  # 예시로 1을 지정

# 결과 카운트
match_count = 0

# trade_df의 각 거래에 대해 처리
for index, trade in trade_df.iterrows():
    # 해당 거래에 대해 날짜와 통화 코드에 맞는 final_df의 행 찾기
    matching_data = final_df[(final_df['Date'] == trade['executedAt'].normalize()) & (final_df['currencyCode'] == trade['currencyCode'])]
    
    # 매칭되는 데이터가 있을 때
    if not matching_data.empty:
        high = matching_data['high'].values[0]
        low = matching_data['low'].values[0]
        
        # 매수 거래인지 매도 거래인지 확인
        if trade['isBuyOrder'] == 1:  # 매수
            if (trade['price'] - threshold >= low) and (trade['price'] - threshold <= high):
                match_count += 1
        else:  # 매도
            if (trade['price'] + threshold >= low) and (trade['price'] + threshold <= high):
                match_count += 1

print(f"조건을 만족하는 거래의 수: {match_count}")
# Out:
# 조건을 만족하는 거래의 수: 0
